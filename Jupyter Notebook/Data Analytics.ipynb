# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
moves = pd.read_csv('moves.csv')
games = pd.read_csv('games.csv')

# %%
moves
# Out:
#     colour      player  calculatedMoves  boardSize  time_allowed  move_number  \
# 0    Black  MonteCarlo              320          5             5            1
# 1    White   AlphaBeta               17          5             5            2
# 2    Black  MonteCarlo              320          5             5            3
# 3    White   AlphaBeta               22          5             5            4
# 4    Black  MonteCarlo              320          5             5            5
# ..     ...         ...              ...        ...           ...          ...
# 183  White   AlphaBeta               11         13             5          144
# 184  Black  MonteCarlo              320         13             5          145
# 185  White   AlphaBeta                7         13             5          146
# 186  Black  MonteCarlo              320         13             5          147
# 187  White   AlphaBeta                3         13             5          148
#
#                                   game_id
# 0    0e3bc481-a45b-11ec-8210-d45d642199dd
# 1    0e3bc481-a45b-11ec-8210-d45d642199dd
# 2    0e3bc481-a45b-11ec-8210-d45d642199dd
# 3    0e3bc481-a45b-11ec-8210-d45d642199dd
# 4    0e3bc481-a45b-11ec-8210-d45d642199dd
# ..                                    ...
# 183  3abf9f23-a45c-11ec-a0ab-d45d642199dd
# 184  3abf9f23-a45c-11ec-a0ab-d45d642199dd
# 185  3abf9f23-a45c-11ec-a0ab-d45d642199dd
# 186  3abf9f23-a45c-11ec-a0ab-d45d642199dd
# 187  3abf9f23-a45c-11ec-a0ab-d45d642199dd
#
# [188 rows x 7 columns]

# %%
games
# Out:
#       player1    player2  player1Territory  player1Captures  player2Territory  \
# 0  MonteCarlo  AlphaBeta                 4               10                 6
# 1  MonteCarlo  AlphaBeta                 3               11                 5
# 2  MonteCarlo  AlphaBeta                23               74                17
#
#    player2Captures  boardSize  time_allowed  \
# 0                0          5             5
# 1                1          5             5
# 2                3         13             5
#
#                                 game_id
# 0  0e3bc481-a45b-11ec-8210-d45d642199dd
# 1  12927f26-a45c-11ec-b1f3-d45d642199dd
# 2  3abf9f23-a45c-11ec-a0ab-d45d642199dd

# %%
plt.plot(moves.player, moves.calculatedMoves)
plt.show()
plt.plot(moves.move_number, moves.calculatedMoves)
plt.show()

# %%
moves.loc[moves['player'] == 'MonteCarlo', ['calculatedMoves', 'move_number', 'boardSize']].plot()
# Out:
# <AxesSubplot:>

# %%
moves.loc[moves['player'] == 'AlphaBeta', ['calculatedMoves', 'move_number']].plot()
# Out:
# <AxesSubplot:>

# %%
games.loc[games['player1'] == 'MonteCarlo', ['player1Territory', 'player1Captures', 'boardSize']].plot()
# Out:
# <AxesSubplot:>

# %%
games.loc[games['player1'] == 'AlphaBeta', ['player1Territory', 'player1Captures', 'boardSize']].plot()
# Out:
# <AxesSubplot:>

# %%
games.loc[games['player2'] == 'AlphaBeta', ['player2Territory', 'player2Captures', 'boardSize']].plot()
# Out:
# <AxesSubplot:>

# %%
games.loc[games['player2'] == 'MonteCarlo', ['player2Territory', 'player2Captures', 'boardSize']].plot()
# Out:
# <AxesSubplot:>
