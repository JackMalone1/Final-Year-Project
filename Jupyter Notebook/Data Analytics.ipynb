# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
moves = pd.read_csv('moves.csv')
games = pd.read_csv('games.csv')

# %%
moves.head(0)
# Out:
# Empty DataFrame
# Columns: [colour, player, calculatedMoves, boardSize, time_allowed, move_number, game_id]
# Index: []

# %%
games.head(0)
# Out:
# Empty DataFrame
# Columns: [player1, player2, player1Territory, player1Captures, player2Territory, player2Captures, boardSize, time_allowed, game_id]
# Index: []

# %%
moves
moves.describe()
# Out:
#        calculatedMoves   boardSize  time_allowed  move_number
# count       370.000000  370.000000    370.000000   370.000000
# mean         78.278378   15.086486      9.918919    75.945946
# std         105.041047    4.508719      5.006112    51.780989
# min           0.000000    5.000000      5.000000     1.000000
# 25%           2.000000   13.000000      5.000000    27.000000
# 50%          43.000000   13.000000      5.000000    73.000000
# 75%         112.500000   19.000000     15.000000   119.000000
# max         320.000000   19.000000     15.000000   182.000000

# %%
moves_calculated = moves[(moves["boardSize"] == 5) & (moves["player"] == "AlphaBeta")].head(100)
moves_calculated.plot(x="move_number", y="calculatedMoves", kind="scatter", label="AlphaBeta")
moves_calculated = moves[(moves["boardSize"] == 5) & (moves["player"] == "MonteCarlo")].head(100)
moves_calculated.plot(x="move_number", y="calculatedMoves", kind="scatter", label="MonteCarlo")
# Out:
# <AxesSubplot:xlabel='move_number', ylabel='calculatedMoves'>

# %%
moves_calculated = moves[(moves["boardSize"] == 13) & (moves["player"] == "AlphaBeta")].head(100)
moves_calculated.plot(x="move_number", y="calculatedMoves", kind="scatter", label="AlphaBeta")
moves_calculated = moves[(moves["boardSize"] == 13) & (moves["player"] == "MonteCarlo")].head(100)
moves_calculated.plot(x="move_number", y="calculatedMoves", kind="scatter", label="MonteCarlo")
# Out:
# <AxesSubplot:xlabel='move_number', ylabel='calculatedMoves'>

# %%
moves_calculated = moves[(moves["boardSize"] == 19) & (moves["player"] == "AlphaBeta")].head(100)
moves_calculated.plot(x="move_number", y="calculatedMoves", kind="scatter", label="AlphaBeta")
moves_calculated = moves[(moves["boardSize"] == 19) & (moves["player"] == "MonteCarlo")].head(100)
moves_calculated.plot(x="move_number", y="calculatedMoves", kind="scatter", label="MonteCarlo")
# Out:
# <AxesSubplot:xlabel='move_number', ylabel='calculatedMoves'>

# %%
games
games.describe()
# Out:
#        player1Territory  player1Captures  player2Territory  player2Captures  \
# count          3.000000         3.000000          3.000000         3.000000
# mean          10.000000        31.666667          9.333333         1.333333
# std           11.269428        36.665151          6.658328         1.527525
# min            3.000000        10.000000          5.000000         0.000000
# 25%            3.500000        10.500000          5.500000         0.500000
# 50%            4.000000        11.000000          6.000000         1.000000
# 75%           13.500000        42.500000         11.500000         2.000000
# max           23.000000        74.000000         17.000000         3.000000
#
#        boardSize  time_allowed
# count   3.000000           3.0
# mean    7.666667           5.0
# std     4.618802           0.0
# min     5.000000           5.0
# 25%     5.000000           5.0
# 50%     5.000000           5.0
# 75%     9.000000           5.0
# ...

# %%
plt.plot(moves.player, moves.calculatedMoves)
plt.show()
plt.plot(moves.move_number, moves.calculatedMoves)
plt.show()

# %%
moves_calculated = moves[(moves["boardSize"] == 5) & (moves["player"] == "AlphaBeta")].head(100)
moves_calculated.plot(x="player", y="calculatedMoves", kind="scatter", label="AlphaBeta")
moves_calculated = moves[(moves["boardSize"] == 5) & (moves["player"] == "MonteCarlo")].head(100)
moves_calculated.plot(x="player", y="calculatedMoves", kind="scatter", label="MonteCarlo")
# Out:
# <AxesSubplot:xlabel='player', ylabel='calculatedMoves'>

# %%
moves.loc[moves['player'] == 'MonteCarlo', ['calculatedMoves', 'move_number', 'boardSize']].plot()
# Out:
# <AxesSubplot:>

# %%
moves.loc[moves['player'] == 'AlphaBeta', ['calculatedMoves', 'move_number']].plot()
# Out:
# <AxesSubplot:>

# %%
games.loc[games['player1'] == 'MonteCarlo', ['player1Territory', 'player1Captures', 'boardSize']].plot()
# Out:
# <AxesSubplot:>

# %%
games.loc[games['player1'] == 'AlphaBeta', ['player1Territory', 'player1Captures', 'boardSize']].plot()
# Out:
# <AxesSubplot:>

# %%
games.loc[games['player2'] == 'AlphaBeta', ['player2Territory', 'player2Captures', 'boardSize']].plot()
# Out:
# <AxesSubplot:>

# %%
games.loc[games['player2'] == 'MonteCarlo', ['player2Territory', 'player2Captures', 'boardSize']].plot()
# Out:
# <AxesSubplot:>

# %%
ax = moves.loc[moves['player'] == 'MonteCarlo'].head().plot(x='calculatedMoves', y='boardSize', kind='barh')
games.loc[games['player1'] == 'MonteCarlo'].head().plot(x='player1Territory', y='boardSize', kind='barh')
plt.show()

# %%
ax = moves.loc[moves['player'] == 'AlphaBeta'].head().plot(x='calculatedMoves', y='boardSize', kind='barh')
#games.loc[games['player1'] == 'AlphaBeta'].plot(x='player1Territory', y='boardSize', kind='barh')
plt.show()

# %%
ax = moves.loc[moves['player'] == 'AlphaBeta'].head().plot(x='calculatedMoves', y='boardSize', kind='barh')
games.loc[games['player2'] == 'AlphaBeta'].head().plot(x='player1Territory', y='boardSize', kind='barh')
plt.show()

# %%
ax = moves.loc[moves['player'] == 'MonteCarlo'].head().plot(x='calculatedMoves', y='boardSize', kind='barh')
#games.loc[games['player2'] == 'MonteCarlo'].plot(x='player1Territory', y='boardSize', kind='barh')
plt.show()

# %%
ax = moves.loc[(moves['player'] == 'MonteCarlo') & (moves['boardSize'] == 19)].head().plot(x='calculatedMoves', y='boardSize', kind='hist')
#games.loc[games['player2'] == 'MonteCarlo'].plot(x='player1Territory', y='boardSize', kind='barh')
plt.show()

# %%
moves.groupby(['player', ])[['calculatedMoves', 'boardSize']].head(5).plot(style='o', kind='barh')
# Out:
# <AxesSubplot:>

# %%
moves.groupby(['player', ])[['calculatedMoves', 'boardSize']].tail(5).plot(style='o', kind='barh')
# Out:
# <AxesSubplot:>

# %%
moves[moves['boardSize'] == 19].groupby(['player', ])[['calculatedMoves', 'boardSize']].head(5).plot(style='o', kind='barh')
# Out:
# <AxesSubplot:>

# %%
moves[moves['boardSize'] == 19].groupby(['player', ])[['calculatedMoves', 'boardSize']].tail(5).plot(style='o', kind='barh')
# Out:
# <AxesSubplot:>

# %%
moves[(moves['boardSize'] == 19) & (moves['player'] == 'MonteCarlo')].groupby(['player', ])[['calculatedMoves', 'boardSize']].head(5).plot(style='o', kind='barh')
# Out:
# <AxesSubplot:>

# %%
moves[(moves['boardSize'] == 19) & (moves['player'] == 'MonteCarlo')].groupby(['player', ])[['calculatedMoves', 'boardSize']].tail(5).plot(style='o', kind='barh')
# Out:
# <AxesSubplot:>

# %%
moves[(moves['boardSize'] == 19) & (moves['player'] == 'AlphaBeta')].groupby(['player', ])[['calculatedMoves', 'boardSize']].head(5).plot(style='o', kind='barh')
# Out:
# <AxesSubplot:>

# %%
moves[(moves['boardSize'] == 19) & (moves['player'] == 'AlphaBeta')].groupby(['player', ])[['calculatedMoves', 'boardSize']].tail(5).plot(style='o', kind='barh')
# Out:
# <AxesSubplot:>

# %%
games[(games['boardSize'] == 5) & (games['player1'] == 'MonteCarlo')].groupby(['player1', ])[['player1Territory','player1Captures']].tail().plot(style='o', kind='barh')
# Out:
# <AxesSubplot:>

# %%
#games[(games['boardSize'] == 5) & (games['player1'] == 'AlphaBeta')].groupby(['player1', ])[['player1Territory','player1Captures']].tail().plot(style='o', kind='barh')

# %%
games[(games['boardSize'] == 5) & (games['player2'] == 'AlphaBeta')].groupby(['player2', ])[['player2Territory','player2Captures']].tail().plot(style='o', kind='barh')
# Out:
# <AxesSubplot:>

# %%
games[(games['boardSize'] == 13) & (games['player2'] == 'AlphaBeta')].groupby(['player2', ])[['player2Territory','player2Captures']].tail().plot(style='o', kind='barh')
# Out:
# <AxesSubplot:>

# %%
games[(games['boardSize'] == 13) & (games['player1'] == 'MonteCarlo')].groupby(['player1', ])[['player1Territory','player1Captures']].tail().plot(style='o', kind='barh')
# Out:
# <AxesSubplot:>
